# %%
import pandas as pd
import numpy as np
# Out:
# The history saving thread hit an unexpected error (DatabaseError('database disk image is malformed')).History will not be written to the database.

# %%
peak_df = pd.read_csv("/cellar/users/aklie/data/datasets/igvf_sc-islet_10X-Multiome/annotation/timecourse/A2_control/snapatac2/filtered/filtered_peaks/SC.beta.filt.narrowPeak", sep="\t", header=None, names=["chrom", "start", "end", "X", "XX", "XXX", "name", "score", "strand", "signalValue", "pValue", "qValue", "peak"])

# %%
# Redo name column with "peak{i}"
peak_df["name"] = ["peak" + str(i) for i in range(1, peak_df.shape[0] + 1)]
peak_df
# Out:
#       chrom      start        end  X XX XXX       name  score strand  \
# 0      chr1       9912      10561  .  .   .      peak1   1000      .
# 1      chr1  231240655  231241684  .  .   .      peak2   1000      .
# 2      chr1  212477106  212477534  .  .   .      peak3   1000      .
# 3      chr1  214660925  214661583  .  .   .      peak4   1000      .
# 4      chr1  214602831  214603561  .  .   .      peak5   1000      .
# ...     ...        ...        ... .. ..  ..        ...    ...    ...
# 70244  chrY    7344762    7345019  .  .   .  peak70245    124      .
# 70245  chrY    2913216    2913452  .  .   .  peak70246    117      .
# 70246  chrY    2838023    2838242  .  .   .  peak70247    105      .
# 70247  chrY    5000714    5001282  .  .   .  peak70248     63      .
# 70248  chrY   13704166   13704590  .  .   .  peak70249     50      .
#
#        signalValue      pValue      qValue  peak
# 0        21.489363  196.430756  193.530823   201
# ...

# %%
peak_df[["chrom", "start", "end", "name", "score", "strand", "signalValue", "pValue", "qValue"]].to_csv("/cellar/users/aklie/data/datasets/igvf_sc-islet_10X-Multiome/annotation/timecourse/A2_control/snapatac2/filtered/homer/known/SC.beta/SC.beta.filt.narrowPeak", sep="\t", header=False, index=False)
