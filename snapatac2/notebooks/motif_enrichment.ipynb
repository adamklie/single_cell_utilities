# %%
import sys
import os
import glob
import snapatac2 as snap
import scanpy as sc
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
in_dir = "/cellar/users/aklie/data/datasets/igvf_sc-islet_10X-Multiome/annotation/timecourse/A2_control/snapatac2/filtered/filtered_peaks"

# %%
# Get list of all narrrowPeak files
narrowPeak_files = glob.glob(os.path.join(in_dir, "*.narrowPeak"))
narrowPeak_files
# Out:
# ['/cellar/users/aklie/data/datasets/igvf_sc-islet_10X-Multiome/annotation/timecourse/A2_control/snapatac2/filtered/filtered_peaks/SC.beta.filt.narrowPeak',
#  '/cellar/users/aklie/data/datasets/igvf_sc-islet_10X-Multiome/annotation/timecourse/A2_control/snapatac2/filtered/filtered_peaks/SC.alpha.filt.narrowPeak',
#  '/cellar/users/aklie/data/datasets/igvf_sc-islet_10X-Multiome/annotation/timecourse/A2_control/snapatac2/filtered/filtered_peaks/SC.EC.1.filt.narrowPeak',
#  '/cellar/users/aklie/data/datasets/igvf_sc-islet_10X-Multiome/annotation/timecourse/A2_control/snapatac2/filtered/filtered_peaks/SC.EC.2.filt.narrowPeak']

# %%
# Load them in as dictionary where key is the sample name and values are lists of "chr:start-end" strings
narrowPeak_dict = {}
for file in narrowPeak_files:
    sample = os.path.basename(file).split(".narrowPeak")[0]
    peaks = []
    with open(file, "r") as f:
        for line in f:
            chrom, start, end = line.strip().split("\t")[:3]
            peaks.append(f"{chrom}:{start}-{end}")
    narrowPeak_dict[sample] = peaks
    print(f"Loaded {len(peaks)} peaks for {sample}")

subsample = 0 # Subsample to speed up testing
if subsample > 0:
    for sample in narrowPeak_dict:
        narrowPeak_dict[sample] = np.random.choice(narrowPeak_dict[sample], size=subsample, replace=False)
        print(f"Subsampled {subsample} peaks for {sample}")
# Out:
# Loaded 70249 peaks for SC.beta.filt
# Loaded 58431 peaks for SC.alpha.filt
# Loaded 46991 peaks for SC.EC.1.filt
# Loaded 45332 peaks for SC.EC.2.filt

# %%
narrowPeak_dict.keys()
# Out:
# dict_keys(['SC.beta.filt', 'SC.alpha.filt', 'SC.EC.1.filt', 'SC.EC.2.filt'])

# %%
motifs = snap.datasets.cis_bp(unique=True)
genome = snap.genome.hg38

# %%
motifs = snap.tl.motif_enrichment(
    motifs=snap.datasets.cis_bp(unique=True),
    regions=narrowPeak_dict,
    genome_fasta=snap.genome.hg38,
)
# Out:
# 2024-03-22 09:34:08 - INFO - Fetching 220668 sequences ...
# 2024-03-22 09:35:10 - INFO - Computing enrichment ...
# 100%|██████████| 1165/1165 [2:12:01<00:00,  6.80s/it]

# %%
motifs
# Out:
# {'SC.beta.filt': shape: (1_165, 6)
#  ┌────────────────────────┬────────────┬────────┬───────────────────┬──────────┬──────────────────┐
#  │ id                     ┆ name       ┆ family ┆ log2(fold change) ┆ p-value  ┆ adjusted p-value │
#  │ ---                    ┆ ---        ┆ ---    ┆ ---               ┆ ---      ┆ ---              │
#  │ str                    ┆ str        ┆ f32    ┆ f64               ┆ f64      ┆ f64              │
#  ╞════════════════════════╪════════════╪════════╪═══════════════════╪══════════╪══════════════════╡
#  │ AC023509.3+M02872_2.00 ┆ AC023509.3 ┆ null   ┆ -0.219312         ┆ 0.000003 ┆ 0.00001          │
#  │ AC138696.1+M04597_2.00 ┆ AC138696.1 ┆ null   ┆ -0.017979         ┆ 0.310968 ┆ 0.337945         │
#  │ AHR+M09817_2.00        ┆ AHR        ┆ null   ┆ -0.163416         ┆ 0.001364 ┆ 0.002507         │
#  │ AIRE+M09375_2.00       ┆ AIRE       ┆ null   ┆ 0.11683           ┆ 0.006165 ┆ 0.010168         │
#  │ …                      ┆ …          ┆ …      ┆ …                 ┆ …        ┆ …                │
#  │ ZSCAN5+M04460_2.00     ┆ ZSCAN5     ┆ null   ┆ 0.008019          ┆ 0.386685 ┆ 0.405717         │
#  │ ZSCAN5C+M08390_2.00    ┆ ZSCAN5C    ┆ null   ┆ 0.166236          ┆ 0.000011 ┆ 0.000029         │
#  │ ZSCAN9+M04466_2.00     ┆ ZSCAN9     ┆ null   ┆ 0.092111          ┆ 0.007224 ┆ 0.011688         │
#  │ ZZZ3+M01272_2.00       ┆ ZZZ3       ┆ null   ┆ 0.126022          ┆ 0.002685 ┆ 0.004703         │
#  └────────────────────────┴────────────┴────────┴───────────────────┴──────────┴──────────────────┘,
#  'SC.alpha.filt': shape: (1_165, 6)
#  ┌────────────────────────┬────────────┬────────┬───────────────────┬──────────┬──────────────────┐
#  │ id                     ┆ name       ┆ family ┆ log2(fold change) ┆ p-value  ┆ adjusted p-value │
#  │ ---                    ┆ ---        ┆ ---    ┆ ---               ┆ ---      ┆ ---              │
#  │ str                    ┆ str        ┆ f32    ┆ f64               ┆ f64      ┆ f64              │
#  ╞════════════════════════╪════════════╪════════╪═══════════════════╪══════════╪══════════════════╡
#  │ AC023509.3+M02872_2.00 ┆ AC023509.3 ┆ null   ┆ -0.072142         ┆ 0.090685 ┆ 0.166375         │
#  │ AC138696.1+M04597_2.00 ┆ AC138696.1 ┆ null   ┆ 0.043268          ┆ 0.130259 ┆ 0.210778         │
#  │ AHR+M09817_2.00        ┆ AHR        ┆ null   ┆ 0.007795          ┆ 0.434394 ┆ 0.459228         │
#  │ AIRE+M09375_2.00       ┆ AIRE       ┆ null   ┆ 0.085786          ┆ 0.053705 ┆ 0.117871         │
#  │ …                      ┆ …          ┆ …      ┆ …                 ┆ …        ┆ …                │
#  │ ZSCAN5+M04460_2.00     ┆ ZSCAN5     ┆ null   ┆ 0.07263           ┆ 0.013526 ┆ 0.049866         │
#  │ ZSCAN5C+M08390_2.00    ┆ ZSCAN5C    ┆ null   ┆ 0.059091          ┆ 0.096403 ┆ 0.174122         │
#  │ ZSCAN9+M04466_2.00     ┆ ZSCAN9     ┆ null   ┆ 0.126849          ┆ 0.00144  ┆ 0.012237         │
#  │ ZZZ3+M01272_2.00       ┆ ZZZ3       ┆ null   ┆ 0.081932          ┆ 0.056849 ┆ 0.121705         │
#  └────────────────────────┴────────────┴────────┴───────────────────┴──────────┴──────────────────┘,
#  'SC.EC.1.filt': shape: (1_165, 6)
#  ┌────────────────────────┬────────────┬────────┬───────────────────┬──────────┬──────────────────┐
#  │ id                     ┆ name       ┆ family ┆ log2(fold change) ┆ p-value  ┆ adjusted p-value │
#  │ ---                    ┆ ---        ┆ ---    ┆ ---               ┆ ---      ┆ ---              │
#  │ str                    ┆ str        ┆ f32    ┆ f64               ┆ f64      ┆ f64              │
#  ╞════════════════════════╪════════════╪════════╪═══════════════════╪══════════╪══════════════════╡
#  │ AC023509.3+M02872_2.00 ┆ AC023509.3 ┆ null   ┆ 0.176244          ┆ 0.000903 ┆ 0.003177         │
#  │ AC138696.1+M04597_2.00 ┆ AC138696.1 ┆ null   ┆ 0.028348          ┆ 0.258492 ┆ 0.30604          │
#  │ AHR+M09817_2.00        ┆ AHR        ┆ null   ┆ 0.130894          ┆ 0.020897 ┆ 0.041334         │
#  │ AIRE+M09375_2.00       ┆ AIRE       ┆ null   ┆ -0.101443         ┆ 0.066077 ┆ 0.103746         │
#  │ …                      ┆ …          ┆ …      ┆ …                 ┆ …        ┆ …                │
#  │ ZSCAN5+M04460_2.00     ┆ ZSCAN5     ┆ null   ┆ -0.00416          ┆ 0.465825 ┆ 0.479828         │
#  │ ZSCAN5C+M08390_2.00    ┆ ZSCAN5C    ┆ null   ┆ -0.133627         ┆ 0.009431 ┆ 0.022607         │
#  │ ZSCAN9+M04466_2.00     ┆ ZSCAN9     ┆ null   ┆ -0.137729         ┆ 0.005181 ┆ 0.013791         │
#  │ ZZZ3+M01272_2.00       ┆ ZZZ3       ┆ null   ┆ -0.11717          ┆ 0.036625 ┆ 0.064649         │
#  └────────────────────────┴────────────┴────────┴───────────────────┴──────────┴──────────────────┘,
#  'SC.EC.2.filt': shape: (1_165, 6)
#  ┌────────────────────────┬────────────┬────────┬───────────────────┬──────────┬──────────────────┐
#  │ id                     ┆ name       ┆ family ┆ log2(fold change) ┆ p-value  ┆ adjusted p-value │
#  │ ---                    ┆ ---        ┆ ---    ┆ ---               ┆ ---      ┆ ---              │
#  │ str                    ┆ str        ┆ f32    ┆ f64               ┆ f64      ┆ f64              │
#  ╞════════════════════════╪════════════╪════════╪═══════════════════╪══════════╪══════════════════╡
#  │ AC023509.3+M02872_2.00 ┆ AC023509.3 ┆ null   ┆ 0.202564          ┆ 0.000211 ┆ 0.000605         │
#  │ AC138696.1+M04597_2.00 ┆ AC138696.1 ┆ null   ┆ -0.060802         ┆ 0.105147 ┆ 0.132285         │
#  │ AHR+M09817_2.00        ┆ AHR        ┆ null   ┆ 0.090631          ┆ 0.084527 ┆ 0.108931         │
#  │ AIRE+M09375_2.00       ┆ AIRE       ┆ null   ┆ -0.211206         ┆ 0.001298 ┆ 0.002836         │
#  │ …                      ┆ …          ┆ …      ┆ …                 ┆ …        ┆ …                │
#  │ ZSCAN5+M04460_2.00     ┆ ZSCAN5     ┆ null   ┆ -0.101258         ┆ 0.007135 ┆ 0.012223         │
#  │ ZSCAN5C+M08390_2.00    ┆ ZSCAN5C    ┆ null   ┆ -0.233455         ┆ 0.000043 ┆ 0.00015          │
#  │ ZSCAN9+M04466_2.00     ┆ ZSCAN9     ┆ null   ┆ -0.206955         ┆ 0.000103 ┆ 0.00032          │
#  │ ZZZ3+M01272_2.00       ┆ ZZZ3       ┆ null   ┆ -0.210689         ┆ 0.000977 ┆ 0.002235         │
#  └────────────────────────┴────────────┴────────┴───────────────────┴──────────┴──────────────────┘}

# %%
motifs["SC.alpha.filt"].to_pandas().sort_values("log2(fold change)", ascending=False).head(50)
# Out:
#                             id          name  family  log2(fold change)  \
# 431          MEF2D+M03343_2.00         MEF2D     NaN           0.246640
# 430          MEF2C+M02745_2.00         MEF2C     NaN           0.243215
# 399          LCORL+M01304_2.00         LCORL     NaN           0.197336
# 230          GATA2+M09550_2.00         GATA2     NaN           0.193471
# 398           LCOR+M02433_2.00          LCOR     NaN           0.185888
# 534          NR2F6+M03386_2.00         NR2F6     NaN           0.185217
# 717            SRF+M03342_2.00           SRF     NaN           0.184234
# 622           RARB+M05564_2.00          RARB     NaN           0.182443
# 996         ZNF443+M07659_2.00        ZNF443     NaN           0.181284
# 1044        ZNF580+M04642_2.00        ZNF580     NaN           0.178470
# 346          HSFY2+M05512_2.00         HSFY2     NaN           0.175384
# 51    BORCS8-MEF2B+M03344_2.00  BORCS8-MEF2B     NaN           0.172888
# 729           TAL2+M08734_2.00          TAL2     NaN           0.172770
# 787          TIGD6+M01205_2.00         TIGD6     NaN           0.170052
# 359           IRF7+M03337_2.00          IRF7     NaN           0.168341
# 428          MEF2A+M10935_2.00         MEF2A     NaN           0.167800
# 828         ZBTB22+M04652_2.00        ZBTB22     NaN           0.163133
# 102         DMRTA1+M10435_2.00        DMRTA1     NaN           0.162558
# 291          HMGA2+M09771_2.00         HMGA2     NaN           0.160246
# 790         TOPORS+M11437_2.00        TOPORS     NaN           0.158049
# 785          TIGD1+M01204_2.00         TIGD1     NaN           0.157891
# 469          MYT1L+M00650_2.00         MYT1L     NaN           0.156053
# 719           ST18+M00650_2.00          ST18     NaN           0.156053
# 901         ZNF181+M07730_2.00        ZNF181     NaN           0.155826
# 1037        ZNF564+M07770_2.00        ZNF564     NaN           0.154448
# 360           IRF8+M03336_2.00          IRF8     NaN           0.153524
# 980         ZNF410+M02882_2.00        ZNF410     NaN           0.153230
# 361           IRF9+M03339_2.00          IRF9     NaN           0.152525
# 356           IRF4+M05539_2.00          IRF4     NaN           0.149099
# 881         ZNF121+M08951_2.00        ZNF121     NaN           0.148897
# 358           IRF6+M05528_2.00          IRF6     NaN           0.146786
# 1130        ZNF787+M04476_2.00        ZNF787     NaN           0.146669
# 670           SIX6+M05357_2.00          SIX6     NaN           0.144830
# 737          TBX19+M05804_2.00         TBX19     NaN           0.144000
# 605          PRDM1+M02731_2.00         PRDM1     NaN           0.142844
# 823         ZBTB16+M10175_2.00        ZBTB16     NaN           0.142726
# 39             BBX+M05764_2.00           BBX     NaN           0.142383
# 523          NR1H2+M09620_2.00         NR1H2     NaN           0.141237
# 829         ZBTB26+M04547_2.00        ZBTB26     NaN           0.140856
# 128           EBF4+M10460_2.00          EBF4     NaN           0.140278
# 101          DMRT3+M04682_2.00         DMRT3     NaN           0.137120
# 535          NR3C1+M05587_2.00         NR3C1     NaN           0.136257
# 353           IRF1+M10879_2.00          IRF1     NaN           0.135774
# 400           LEF1+M05775_2.00          LEF1     NaN           0.135552
# 233          GATA5+M04870_2.00         GATA5     NaN           0.135276
# 925         ZNF250+M08264_2.00        ZNF250     NaN           0.134812
# 715         SREBF1+M09798_2.00        SREBF1     NaN           0.133746
# 354           IRF2+M10893_2.00          IRF2     NaN           0.133515
# 512         NKX3-1+M10730_2.00        NKX3-1     NaN           0.132304
# 743           TBX4+M03559_2.00          TBX4     NaN           0.132152
#
#            p-value  adjusted p-value
# 431   0.000000e+00      0.000000e+00
# 430   0.000000e+00      0.000000e+00
# 399   2.243863e-05      4.149366e-04
# 230   8.811913e-08      2.933108e-06
# 398   1.580203e-04      2.217995e-03
# 534   2.275884e-09      1.152785e-07
# 717   3.964280e-03      2.359060e-02
# 622   1.281595e-08      5.742530e-07
# 996   0.000000e+00      0.000000e+00
# 1044  1.690466e-04      2.316932e-03
# 346   1.183216e-01      1.972026e-01
# 51    7.590535e-06      1.607813e-04
# 729   1.102597e-05      2.214700e-04
# 787   4.605815e-02      1.086189e-01
# 359   1.932752e-06      4.595215e-05
# 428   2.155680e-06      4.924250e-05
# 828   4.001772e-02      9.874327e-02
# 102   8.159710e-04      8.338651e-03
# 291   1.145943e-02      4.525505e-02
# 790   1.101293e-09      6.415033e-08
# 785   4.272445e-02      1.039123e-01
# 469   9.071140e-06      1.854014e-04
# 719   9.071140e-06      1.854014e-04
# 901   0.000000e+00      0.000000e+00
# 1037  4.031925e-05      7.010735e-04
# 360   1.961025e-04      2.596130e-03
# 980   9.665008e-03      4.064886e-02
# 361   3.587728e-05      6.430312e-04
# 356   1.236734e-03      1.099843e-02
# 881   0.000000e+00      0.000000e+00
# 358   3.851540e-02      9.649558e-02
# 1130  3.773093e-12      2.747283e-10
# 670   1.085164e-01      1.861695e-01
# 737   2.200015e-02      6.701615e-02
# 605   2.115406e-06      4.924250e-05
# 823   1.906836e-04      2.583097e-03
# 39    2.796217e-02      7.840944e-02
# 523   1.896757e-05      3.564068e-04
# 829   1.156842e-04      1.750286e-03
# 128   8.099813e-03      3.534188e-02
# 101   1.178195e-02      4.633955e-02
# 535   2.039534e-02      6.336154e-02
# 353   4.221285e-05      7.232054e-04
# 400   2.804122e-04      3.438739e-03
# 233   2.720970e-02      7.712724e-02
# 925   1.063357e-03      9.831831e-03
# 715   5.000916e-05      8.443575e-04
# 354   9.376007e-10      5.748972e-08
# 512   9.769623e-03      4.079430e-02
# 743   4.996677e-03      2.658049e-02

# %%
snap.pl.motif_enrichment(motifs, min_log_fc=0.25, max_fdr=1e-8, height=1600, interactive=False)
