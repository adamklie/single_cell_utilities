# %% [markdown]
# # Perform some initial analysis on the results of the SnapATAC2 pipeline
# **Authorship:** Adam Klie (last updated: 08/22/2023)<br>
# ***
# **Description:** Notebook to plot and plan next steps from a baseline SnapATAC2 run. Expects that you have run all steps up to and including `7_analyze_anndataset.sh`. This is somewhat of a playground and thus will need to be interactive.

# %% [markdown]
# # Set-up

# %%
# Import packages
import os
import numpy as np
import pandas as pd
import snapatac2 as snap
import scanpy as sc

# %%
barcodes_path = "/cellar/users/aklie/data/datasets/igvf_sc-islet_10X-Multiome/annotation/annotations.txt"
barcodes = pd.read_csv(barcodes_path, header=None, index_col=0, sep="\t")
barcodes = barcodes.index.tolist()

# %%
adata = snap.read("/cellar/users/aklie/data/datasets/igvf_sc-islet_10X-Multiome/annotation/sample/dm14b/snapatac2/clustered_obsm_delete.h5ad")
adata
# Out:
# AnnData object with n_obs x n_vars = 2761 x 606219 backed at '/cellar/users/aklie/data/datasets/igvf_sc-islet_10X-Multiome/annotation/sample/dm14b/snapatac2/clustered_obsm_delete.h5ad'
#     obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse', 'log_n_fragment', 'doublet_probability', 'doublet_score', 'leiden_1'
#     var: 'count', 'selected'
#     uns: 'reference_sequences', 'doublet_rate', 'scrublet_sim_doublet_score', 'spectral_eigenvalue', 'frag_size_distr', 'leiden_1_colors'
#     obsm: 'fragment_paired'
#     obsp: 'distances'

# %%
adata.subset(obs_indices=np.where(pd.Index(adata.obs_names).isin(barcodes))[0])
adata
# Out:
# AnnData object with n_obs x n_vars = 2761 x 606219 backed at '/cellar/users/aklie/data/datasets/igvf_sc-islet_10X-Multiome/annotation/sample/dm14b/snapatac2/clustered_obsm_delete.h5ad'
#     obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse', 'log_n_fragment', 'doublet_probability', 'doublet_score', 'leiden_1'
#     var: 'count', 'selected'
#     uns: 'reference_sequences', 'doublet_rate', 'scrublet_sim_doublet_score', 'spectral_eigenvalue', 'frag_size_distr', 'leiden_1_colors'
#     obsm: 'fragment_paired'
#     obsp: 'distances'

# %%
adata.close()

# %%
adataset = snap.read_dataset("/cellar/users/aklie/data/datasets/igvf_sc-islet_10X-Multiome/annotation/timecourse/A2_ext4/snapatac2/merged.h5ads")

# %%
len(adataset.obs_names)
# Out:
# 35106

# %%
adata = adataset.to_adata()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 adata = adataset.to_adata()
#
# File ~/opt/miniconda3/envs/scverse-lite-py39/lib/python3.9/site-packages/anndata/_core/anndata.py:920, in AnnData.obs(self, value)
#     918 @obs.setter
#     919 def obs(self, value: pd.DataFrame):
# --> 920     self._set_dim_df(value, "obs")
#
# File ~/opt/miniconda3/envs/scverse-lite-py39/lib/python3.9/site-packages/anndata/_core/anndata.py:859, in AnnData._set_dim_df(self, value, attr)
#     857 if not isinstance(value, pd.DataFrame):
#     858     raise ValueError(f"Can only assign pd.DataFrame to {attr}.")
# --> 859 value_idx = self._prep_dim_index(value.index, attr)
#     860 if self.is_view:
#     861     self._init_as_actual(self.copy())
#
# File ~/opt/miniconda3/envs/scverse-lite-py39/lib/python3.9/site-packages/anndata/_core/anndata.py:873, in AnnData._prep_dim_index(self, value, attr)
#     868 """Prepares index to be uses as obs_names or var_names for AnnData object.AssertionError
#     869
#     870 If a pd.Index is passed, this will use a reference, otherwise a new index object is created.
#     871 """
#     872 if self.shape[attr == "var"] != len(value):
# --> 873     raise ValueError(
#     874         f"Length of passed value for {attr}_names is {len(value)}, but this AnnData has shape: {self.shape}"
#     875     )
#     876 if isinstance(value, pd.Index) and not isinstance(
#     877     value.name, (str, type(None))
#     878 ):
#     879     raise ValueError(
#     880         f"AnnData expects .{attr}.index.name to be a string or None, "
#     881         f"but you passed a name of type {type(value.name).__name__!r}"
#     882     )
#
# ValueError: Length of passed value for obs_names is 35106, but this AnnData has shape: (29846, 606219)

# %%
sc.pl.umap(adata, color="leiden_1")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 sc.pl.umap(adataset, color="leiden_1")
#
# File ~/opt/miniconda3/envs/scverse-lite-py39/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:691, in umap(adata, **kwargs)
#     632 @_wraps_plot_scatter
#     633 @_doc_params(
#     634     adata_color_etc=doc_adata_color_etc,
#    (...)
#     638 )
#     639 def umap(adata, **kwargs) -> Union[Axes, List[Axes], None]:
#     640     """\
#     641     Scatter plot in UMAP basis.
#     642
#    (...)
#     689     tl.umap
#     690     """
# --> 691     return embedding(adata, 'umap', **kwargs)
#
# File ~/opt/miniconda3/envs/scverse-lite-py39/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:133, in embedding(adata, basis, color, gene_symbols, use_raw, sort_order, edges, edges_width, edges_color, neighbors_key, arrows, arrows_kwds, groups, components, dimensions, layer, projection, scale_factor, color_map, cmap, palette, na_color, na_in_legend, size, frameon, legend_fontsize, legend_fontweight, legend_loc, legend_fontoutline, colorbar_loc, vmax, vmin, vcenter, norm, add_outline, outline_width, outline_color, ncols, hspace, wspace, title, show, save, ax, return_fig, **kwargs)
#     128 #####################
#     129 # Argument handling #
#     130 #####################
#     132 check_projection(projection)
# --> 133 sanitize_anndata(adata)
#     135 basis_values = _get_basis(adata, basis)
#     136 dimensions = _components_to_dimensions(
#     137     components, dimensions, projection=projection, total_dims=basis_values.shape[1]
#     138 )
#
# File ~/opt/miniconda3/envs/scverse-lite-py39/lib/python3.9/site-packages/scanpy/_utils/__init__.py:405, in sanitize_anndata(adata)
#     403 def sanitize_anndata(adata):
#     404     """Transform string annotations to categoricals."""
# --> 405     adata._sanitize()
#
# AttributeError: 'builtins.AnnDataSet' object has no attribute '_sanitize'

# %%
adataset.close()

# %%
# Paths
input_h5ad_path = "/cellar/users/aklie/data/datasets/igvf_sc-islet_10X-Multiome/annotation/16Aug23/snapatac2/processed/adata_atac_MO1_processed.h5ad"

# %% [markdown]
# # Load the data

# %%
# Load h5ad
adata = sc.read_h5ad(input_h5ad_path)
adata
# Out:
# AnnData object with n_obs × n_vars = 2780 × 606219
#     obs: 'tsse', 'n_fragment', 'frac_dup', 'frac_mito', 'doublet_probability', 'doublet_score'
#     var: 'count', 'selected'
#     uns: 'reference_sequences', 'scrublet_sim_doublet_score'
#     obsm: 'insertion'

# %% [markdown]
# # Quick checks

# %%
# Plot tsse
snap.pl.tsse(adata, interactive=False)

# %%
# How many cells are kept?
adata_mem.obs["kept"] = snap.pp.filter_cells(adata_mem, min_counts=10000, min_tsse=10, max_counts=65000, inplace=False).values
adata_mem.obs["kept"].value_counts()
# Out:
# True     7927
# False    3000
# Name: kept, dtype: int64

# %%
# Actually perform the filtering
adata_pp = adata_mem[adata_mem.obs["kept"]].copy()

# %%
snap.pp.add_tile_matrix(adata_pp)

# %%
snap.pp.select_features(adata_pp, n_features=250000)
# Out:
# 2023-10-18 14:03:31 - INFO - Selected 250000 features.

# %%
#snap.pp.scrublet(adata_pp)

# %%
adata_pp.var["selected"].value_counts()
# Out:
# False    5812095
# True      250000
# Name: selected, dtype: int64

# %%
snap.tl.spectral(adata_pp)

# %%
snap.tl.umap(adata_pp)

# %%
snap.pp.knn(adata_pp)
snap.tl.leiden(adata_pp)

# %%
snap.pl.umap(adata_pp, color='leiden', show=True, height=500)
# Out:
# <div>                            <div id="58a2584b-099c-4312-9034-8338ec46c6fa" class="plotly-graph-div" style="height:500px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("58a2584b-099c-4312-9034-8338ec46c6fa")) {                    Plotly.newPlot(                        "58a2584b-099c-4312-9034-8338ec46c6fa",                        [{"hovertemplate":"leiden=0<br>UMAP-1=%{x}<br>UMAP-2=%{y}<extra></extra>","legendgroup":"0","marker":{"color":"#2E91E5","symbol":"circle","opacity":1,"size":1.5045904537030634},"mode":"markers","name":"0","showlegend":true,"x":[9.185311317443848,9.046250343322754,7.122490882873535,8.922181129455566,8.497945785522461,8.620718002319336,8.419839859008789,7.896059036254883,7.547664642333984,8.596778869628906,8.652099609375,8.933510780334473,7.4221296310424805,8.83281135559082,8.117107391357422,7.29667329788208,8.854231834411621,8.644475936889648,9.082304954528809,8.355237007141113,7.735544204711914,7.298440933227539,9.204407691955566,9.0431547164917,7.11085319519043,6.9753570556640625,9.29327392578125,9.237785339355469,9.253815650939941,8.58125114440918,9.104299545288086,8.32404899597168,8.264345169067383,9.008054733276367,9.45600700378418,8.8268404006958,9.007648468017578,7.834993362426758,7.566636085510254,7.848005771636963,8.36534595489502,8.661927223205566,8.198528289794922,8.758461952209473,8.301897048950195,8.160828590393066,8.438176155090332,8.977041244506836,8.720308303833008,8.343098640441895,7.987614631652832,8.938623428344727,9.23725700378418,8.38696575164795,9.140501022338867,9.120101928710938,9.546548843383789,7.2852277755737305,8.160927772521973,8.9202241897583,8.076592445373535,8.034971237182617,7.9996538162231445,7.037408351898193,9.38597583770752,7.727390289306641,9.155004501342773,8.20111083984375,8.206136703491211,7.622694492340088,9.154746055603027,8.533614158630371,7.039018630981445,8.518754959106445,7.343793869018555,7.417880535125732,7.747220993041992,9.094325065612793,9.441191673278809,7.792926788330078,8.716464042663574,8.049920082092285,8.27700424194336,7.043117046356201,8.706864356994629,8.083746910095215,8.962172508239746,7.632996559143066,9.056785583496094,8.250286102294922,9.479095458984375,8.294053077697754,7.626718997955322,9.323890686035156,8.571390151977539,9.21034049987793,8.502873420715332,9.253037452697754,8.727059364318848,8.484634399414062,8.487448692321777,8.334178924560547,8.90673542022705,8.070531845092773,7.361785888671875,8.619937896728516,6.0259318351745605,9.188591957092285,9.29517936706543,8.328337669372559,8.330901145935059,8.999126434326172,7.219353675842285,9.168901443481445,5.9305644035339355,9.04631233215332,8.815935134887695,8.088335990905762,8.417247772216797,8.258761405944824,7.787586688995361,8.579264640808105,8.074125289916992,8.865045547485352,8.059566497802734,8.34176254272461,8.19527816772461,8.26867389678955,7.960593223571777,8.167543411254883,7.186808109283447,9.546675682067871,8.788586616516113,8.633503913879395,8.759187698364258,7.138676166534424,9.238948822021484,8.496253967285156,8.341238021850586,7.890355110168457,8.479848861694336,8.45653247833252,8.537150382995605,9.272415161132812,7.877162456512451,7.634817123413086,9.188196182250977,7.725275039672852,7.496261119842529,7.46616268157959,9.280202865600586,8.817327499389648,9.139198303222656,8.31169319152832,9.006247520446777,8.999075889587402,9.339674949645996,9.024023056030273,9.200098991394043,8.754509925842285,8.685481071472168,8.048201560974121,9.236285209655762,7.932456016540527,8.160016059875488,8.259688377380371,7.521297454833984,9.185905456542969,7.988897323608398,8.477540969848633,8.133322715759277,9.387959480285645,8.482161521911621,8.533390045166016,8.896272659301758,8.75019359588623,8.26606273651123,9.131545066833496,8.566899299621582,8.024555206298828,8.779202461242676,8.529562950 ...

# %%
gene_matrix = snap.pp.make_gene_matrix(adata_pp, snap.genome.hg38)

# %%
gene_matrix
# Out:
# AnnData object with n_obs × n_vars = 7927 × 60606
#     obs: 'tsse', 'n_fragment', 'frac_dup', 'frac_mito', 'kept', 'leiden'

# %%
import scanpy as sc

# %%
sc.pp.filter_genes(gene_matrix, min_cells=5)
sc.pp.normalize_total(gene_matrix)
sc.pp.log1p(gene_matrix)

# %%
sc.external.pp.magic(gene_matrix, solver="approximate")

# %%
gene_matrix.obsm["X_umap"] = adata_pp.obsm["X_umap"]

# %%
# Define global run parameters
marker_genes = {
    "SC.beta": ["INS", "IAPP", "PDX1", "ISL1"],
    "SC.pre.alpha": ["ARX"],
    "SC.alpha": ["GCG"],
    "SC.delta": ["SST"],
    "SC.EC": ["TPH1", "CHGA", "NKX6-1"],
    "progenitor": ["PTF1A", "NEUROG3", "ZEB2", "SOX9"]
}

# %%
gene_matrix.X
# Out:
# array([[ 7.73682912e-02,  1.16289052e-02,  3.91586273e-03, ...,
#          4.29826684e-03,  1.06151272e-03, -7.68252109e-04],
#        [ 8.39473659e-02,  1.40886580e-02,  5.17575371e-03, ...,
#          5.16964779e-03,  6.32865626e-05,  2.32026775e-03],
#        [ 8.10675733e-02,  1.53462617e-02,  5.32161649e-03, ...,
#          7.89113349e-03,  1.59755008e-03,  1.25417746e-03],
#        ...,
#        [ 7.34879046e-02,  1.58906441e-02,  5.52164563e-03, ...,
#          8.12777849e-03,  1.67701489e-03,  6.16033355e-04],
#        [ 7.94008358e-02,  1.65445299e-02,  5.07096847e-03, ...,
#          2.19355856e-03,  9.07201805e-04,  9.75264884e-04],
#        [ 7.87991194e-02,  1.44400057e-02,  3.92459993e-03, ...,
#          3.09297273e-03, -8.48279322e-05,  2.01692922e-03]])

# %%
marker_genes_in_data = dict()
for ct, markers in marker_genes.items():
    markers_found = list()
    for marker in markers:
        if marker in gene_matrix.var.index:
            markers_found.append(marker)
    marker_genes_in_data[ct] = markers_found
marker_genes_in_data
# Out:
# {'SC.beta': ['INS', 'IAPP', 'PDX1', 'ISL1'],
#  'SC.pre.alpha': ['ARX'],
#  'SC.alpha': ['GCG'],
#  'SC.delta': ['SST'],
#  'SC.EC': ['TPH1', 'CHGA', 'NKX6-1'],
#  'progenitor': ['PTF1A', 'NEUROG3', 'ZEB2', 'SOX9']}

# %%
for ct in marker_genes_in_data.keys():
    print(f"{ct.upper()}:")  # print cell subtype name
    sc.pl.umap(
        gene_matrix,
        color=marker_genes_in_data[ct],
        vmin=0,
        vmax="p99",  # set vmax to the 99th percentile of the gene count instead of the maximum, to prevent outliers from making expression in other cells invisible. Note that this can cause problems for extremely lowly expressed genes.
        sort_order=False,  # do not plot highest expression on top, to not get a biased view of the mean expression among cells
        frameon=False,
        cmap="Reds",  # or choose another color map e.g. from here: https://matplotlib.org/stable/tutorials/colors/colormaps.html
    )
    print("\n\n\n")  # print white space for legibility
# Out:
# ... storing 'leiden' as categorical
# SC.BETA:
# SC.PRE.ALPHA:
# SC.ALPHA:
# SC.DELTA:
# SC.EC:
# PROGENITOR:
