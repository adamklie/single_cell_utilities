# %% [markdown]
# # Count up reads in peaks, subset cell-type specific and link peaks to genes

# %% [markdown]
# **Authorship:**
# Author, *MM/DD/YYYY*
# ***
# **Description:**
# Notebook to do some cool stuff
# ***
# **TODOs:**
#  - <font color='red'> count up reads in peaks </font>
#  - <font color='red'> subset to cell-type specific objects per sample </font>
#  - <font color='red'> link peaks to genes </font>
# ***

# %% [markdown]
# # Set-up

# %%
# Load libraries, takes between 20s and 1 min
suppressMessages(library(Signac))
suppressMessages(library(Seurat))
suppressMessages(library(EnsDb.Hsapiens.v86))
suppressMessages(library(BSgenome.Hsapiens.UCSC.hg38))
suppressMessages(library(harmony))
suppressMessages(library(SeuratDisk))
suppressMessages(library(ggplot2))
options(future.globals.maxSize = 4000 * 1024^2)
warnLevel <- getOption('warn')
options(warn = -1)
set.seed(1234)

# %%
# Load in genomic annotations from the interwebs. Takes about 5 mins
print("Loading hg38 genome annotations from Ensembl")
annotations <- GetGRangesFromEnsDb(ensdb=EnsDb.Hsapiens.v86)
seqlevelsStyle(annotations) <- 'UCSC'
genome(annotations) <- 'hg38'
# Out:
# [1] "Loading hg38 genome annotations from Ensembl"
# Fetching data...
# OK
#
# Parsing exons...
# OK
# Defining introns...
# OK
# Defining UTRs...
# OK
# Defining CDS...
# OK
#
# aggregating...
#
# Done
#
# Fetching data...
# OK
#
# Parsing exons...
# OK
# Defining introns...
# OK
# Defining UTRs...
# OK
# Defining CDS...
# OK
#
# aggregating...
#
# Done
#
# Fetching data...
# OK
#
# Parsing exons...
# OK
# Defining introns...
# OK
# Defining UTRs...
# OK
# Defining CDS...
# OK
#
# aggregating...
#
# Done
#
# Fetching data...
# OK
#
# Parsing exons...
# OK
# Defining introns...
# OK
# Defining UTRs...
# OK
# Defining CDS...
# OK
#
# aggregating...
#
# Done
#
# Fetching data...
# OK
#
# Parsing exons...
# OK
# Defining introns...
# OK
# Defining UTRs...
# OK
# Defining CDS...
# OK
#
# aggregating...
#
# Done
#
# Fetching data...
# OK
#
# Parsing exons...
# OK
# Defining introns...
# OK
# Defining UTRs...
# OK
# Defining CDS...
# OK
#
# aggregating...
#
# Done
#
# Fetching data...
# OK
#
# Parsing exons...
# OK
# Defining introns...
# OK
# Defining UTRs...
# OK
# Defining CDS...
# OK
#
# aggregating...
#
# Done
#
# Fetching data...
# OK
#
# Parsing exons...
# OK
# Defining introns...
# OK
# Defining UTRs...
# OK
# Defining CDS...
# OK
#
# aggregating...
#
# Done
#
# Fetching data...
# OK
#
# Parsing exons...
# OK
# Defining introns...
# OK
# Defining UTRs...
# OK
# Defining CDS...
# OK
#
# aggregating...
#
# Done
#
# Fetching data...
# OK
#
# Parsing exons...
# OK
# Defining introns...
# OK
# Defining UTRs...
# OK
# Defining CDS...
# OK
#
# aggregating...
#
# Done
#
# Fetching data...
# OK
#
# Parsing exons...
# OK
# Defining introns...
# OK
# Defining UTRs...
# OK
# Defining CDS...
# OK
#
# aggregating...
#
# Done
#
# Fetching data...
# OK
#
# Parsing exons...
# OK
# Defining introns...
# OK
# Defining UTRs...
# OK
# Defining CDS...
# OK
#
# aggregating...
#
# Done
#
# Fetching data...
# OK
#
# Parsing exons...
# OK
# Defining introns...
# OK
# Defining UTRs...
# OK
# Defining CDS...
# OK
#
# aggregating...
#
# Done
#
# Fetching data...
# OK
#
# Parsing exons...
# OK
# Defining introns...
# OK
# Defining UTRs...
# OK
# Defining CDS...
# OK
#
# aggregating...
#
# Done
#
# Fetching data...
# OK
#
# Parsing exons...
# OK
# Defining introns...
# OK
# Defining UTRs...
# OK
# Defining CDS...
# OK
#
# aggregating...
#
# Done
#
# Fetching data...
# OK
#
# Parsing exons...
# OK
# Defining introns...
# OK
# Defining UTRs...
# OK
# Defining CDS...
# OK
#
# aggregating...
#
# Done
#
# Fetching data...
# OK
#
# Parsing exons...
# OK
# Defining introns...
# OK
# Defining UTRs...
# OK
# Defining CDS...
# OK
#
# aggregating...
#
# Done
#
# Fetching data...
# OK
#
# Parsing exons...
# OK
# Defining introns...
# OK
# Defining UTRs...
# OK
# Defining CDS...
# OK
#
# aggregating...
#
# Done
#
# Fetching data...
# OK
#
# Parsing exons...
# OK
# Defining introns...
# OK
# Defining UTRs...
# OK
# Defining CDS...
# OK
#
# aggregating...
#
# Done
#
# Fetching data...
# OK
#
# Parsing exons...
# OK
# Defining introns...
# OK
# Defining UTRs...
# OK
# Defining CDS...
# OK
#
# aggregating...
#
# Done
#
# Fetching data...
# OK
#
# Parsing exons...
# OK
# Defining introns...
# OK
# Defining UTRs...
# OK
# Defining CDS...
# OK
#
# aggregating...
#
# Done
#
# Fetching data...
# OK
#
# Parsing exons...
# OK
# Defining introns...
# OK
# Defining UTRs...
# OK
# Defining CDS...
# OK
#
# aggregating...
#
# Done
#
# Fetching data...
# OK
#
# Parsing exons...
# OK
# Defining introns...
# OK
# Defining UTRs...
# OK
# Defining CDS...
# OK
#
# aggregating...
#
# Done
#
# Fetching data...
# OK
#
# Parsing exons...
# OK
# Defining introns...
# OK
# Defining UTRs...
# OK
# Defining CDS...
# OK
#
# aggregating...
#
# Done
#
# Fetching data...
# OK
#
# Parsing exons...
# OK
# Defining introns...
# OK
# Defining UTRs...
# OK
# Defining CDS...
# OK
#
# aggregating...
#
# Done

# %% [markdown]
# # Load all needed data

# %% [markdown]
# ## SCT assay for sample
# Only need the SCT assay to perform correlation with counts

# %%
# Set-up sample and cell-type, will be arguments in script
sample <- "R207"
cell.type <- "delta"
print(sprintf("Creating CRE-gene links for %s cells in sample %s", cell.type, sample))
# Out:
# [1] "Creating CRE-gene links for delta in sample R207"

# %%
# Load in the Seurat object
path = file.path("../indv_sample_analysis", sprintf("%s.indv.analysis.h5seurat", sample))
print(sprintf("Loading from %s", path))
adata <- LoadH5Seurat(path, assays = c("SCT"), reductions = c("pca"), graphs = FALSE, neighbors = FALSE, verbose = FALSE)
table(adata$predicted.id)
# Out:
# [1] "Loading from ../indv_sample_analysis/R207.indv.analysis.h5seurat"
# Validating h5Seurat file
#             acinar activated_stellate              alpha               beta
#                655                 17               3072               4141
#              delta             ductal        endothelial              gamma
#                409                 76                 22                166
#         macrophage               mast quiescent_stellate
#                 30                 17                  6

# %%
# Grab cell-type ideas
ids <- colnames(adata)[adata$predicted.id == cell.type]
# Out:
#   [1] "AAACCAACAAGTGAAC-1" "AAACCGGCAATCCTGA-1" "AAACCGGCATCACTTC-1"
#   [4] "AAACGCGCAAGCTACC-1" "AAAGCTTGTGATTTGG-1" "AAAGCTTGTGTTGTGA-1"
#   [7] "AAAGGTTAGCTATTGA-1" "AACAAGCCACACAATT-1" "AACATTGTCAAGTGTC-1"
#  [10] "AACCTAATCATTACGA-1" "AACCTAATCGTCCTTA-1" "AACCTCACAAGGTCGA-1"
#  [13] "AACGCCCAGGCATTGT-1" "AACGCTAGTGCGCATG-1" "AACTTAGTCCTTAAGA-1"
#  [16] "AAGACATAGATGGAGC-1" "AAGACATAGCAACATC-1" "AAGCATGAGAACAAGT-1"
#  [19] "AAGCCTGTCAATGAGG-1" "AAGCCTGTCTTTGACT-1" "AAGCGGGTCCTTGCAC-1"
#  [22] "AAGCGTTTCCGGGACT-1" "AAGGATTAGCTAATTG-1" "AAGTTTGTCGCAAACT-1"
#  [25] "AATATCCCAGGCCTTG-1" "AATATCCCAGTTATGT-1" "AATCCTAAGGCCTAAT-1"
#  [28] "AATTTGCCAGTTGCGT-1" "ACAAAGGTCAGTGAAG-1" "ACAACAACAGTAAGTA-1"
#  [31] "ACAACACTCCCGCAAA-1" "ACAGGATCACGTTACA-1" "ACATCAATCCGCTAGA-1"
#  [34] "ACATCAATCTATCGCC-1" "ACCCAACCACATACTG-1" "ACCCGCTGTTTGACCT-1"
#  [37] "ACCCGTAAGTCACTCC-1" "ACCTAAGGTGCTGGTG-1" "ACCTGTTGTTGGTTGA-1"
#  [40] "ACCTTGTGTATTCGTC-1" "ACGACTTAGCAATAGG-1" "ACGCAAGCACCTGCCT-1"
#  [43] "ACGGGAAGTGTCCTGC-1" "ACGTCAAGTCACAAAT-1" "ACGTCCAAGTCCTTCA-1"
#  [46] "ACGTCCAAGTTAGTGC-1" "ACGTTACAGGTATTGC-1" "ACTAAAGCAGGCTAAG-1"
#  [49] "ACTTCGCTCCTACCTA-1" "ACTTGAATCAAGCTTA-1" "ACTTTGTTCCATTACT-1"
#  [52] "AGAACAAGTGCAATAT-1" "AGAGATTAGGGCCATC-1" "AGAGGAACATGTCGCG-1"
#  [55] "AGCAACAAGTCCTTCA-1" "AGCGGACCAGTAAAGC-1" "AGCTACTAGGACGTAA-1"
#  [58] "AGCTTGGTCATGCGTG-1" "AGCTTTAAGATTGAGG-1" "AGGAACCAGATGGAGC-1"
#  [61] "AGGAACGGTACCTTAC-1" "AGGACGTAGGACCGCT-1" "AGGATCCGTGTTGTAG-1"
#  [64] "AGGCAGGTCTGGCTTC-1" "AGGCTAAAGGTCGATT-1" "AGGTTAGAGCCTAACG-1"
#  [67] "AGGTTTGGTCGCAATA-1" "AGTCCTGAGGAGTAAT-1" "AGTGGACAGCTTATGA-1"
#  [70] "AGTTGTCAGCTATGAC-1" "ATAAGTCGTCGTTATC-1" "ATAAGTCGTTGCGCGA-1"
#  [73] "ATACCGGTCGCACACA-1" "ATACCTGCACTTAGGC-1" "ATATGCATCGGCTATG-1"
#  [76] "ATATGCTCAGAAATTG-1" "ATATGGTGTTCCGGCT-1" "ATATGGTGTTGTAAAC-1"
#  [79] "ATCAAGACACCCACAG-1" "ATCATCAAGCACGATT-1" "ATCCATAAGCTGGCTA-1"
#  [82] "ATCCCGCGTCCTAAGA-1" "ATCGAGGCATCCCGCT-1" "ATGAAGTAGAGGGACT-1"
#  [85] "ATGACAACAGTAGGAT-1" "ATGACTCAGAAGGTGC-1" "ATGAGCCGTTAGACCA-1"
#  [88] "ATGGTCTAGGTCTTGG-1" "ATGTTGTCACAGAACG-1" "ATTGAAGCATAGACCC-1"
#  [91] "ATTGCGCCATTATGCG-1" "ATTGGTTCATCTTGAG-1" "ATTGTGATCGAGGAAC-1"
#  [94] "CAAACACTCGTTAGTA-1" "CAAATCATCCTAAGTA-1" "CAATAGCTCAAACACC-1"
#  [97] "CAATCCCTCTTGACCC-1" "CAATCTAAGAGGAGTC-1" "CAATCTAAGCCTGGTA-1"
# [100] "CACAATATCTGTGCAG-1" "CACATAATCGAGGAGT-1" "CACCAACCAATATGGA-1"
# [103] "CACCAACCAGAGGCTA-1" "CAGATTCAGTAACTCA-1" "CAGCCTAAGTCCTTCA-1"
# [106] "CAGGCTATCGGGATTT-1" "CAGGGCTTCACGAATC-1" "CATAAGCTCGTTAAGC-1"
# [109] "CATAGACTCATCACTT-1" "CATAGCTAGGGACTAA-1" "CATCACACAGCACGTT-1"
# [112] "CATGCATAGGCCTTAG-1" "CATGGATTCCAGCACA-1" "CATGGCGGTTAGCGTA-1"
# [115] "CATTCATTCCTAATGA-1" "CATTGTGCAACGTGCT-1" "CATTTGTTCTGTGCCT-1"
# [118] "CCAAACCCAAGGTCCT-1" "CCATAAGGTAACGGGA-1" "CCATCATGTCATGAGC-1"
# [121] "CCCATAACACTTAACG-1" "CCCTAATGTGACCTGG-1" "CCCTAATGTGTTCCCA-1"
# [124] "CCCTCAGTCGAAGTGA-1" "CCGCAAATCTAACCAA-1" "CCGCACACATGAAATG-1"
# [127] "CCGCCAACACCTCAGG-1" "CCGCCAACACTTACAG-1" "CCGCTAAAGGCTCATG-1"
# [130] "CCGTTATGTCTTTGAC-1" "CCTCAATGTTTAGTCC-1" "CCTCAGTTCCATAATG-1"
# [133] "CCTCAGTTCTGGCTTC-1" "CCTGTAACAGAAATGC-1" "CCTTATGTCGCATCCT-1"
# [136] "CCTTCGGTCAAACCGT-1" "CCTTGCGTCCTTGCAC-1" "CGAACAAAGCGCCTAA-1"
# [139] "CGAAGTAAGCGGATTT-1" "CGAATCTAGCTTTGGG-1" "CGACAAGCATGCTATG-1"
# [142] "CGACCTGCATGTTTGG-1" "CGAGCGAAGAACCTGT-1" "CGAGGAAGTCTCACTG-1"
# [145] "CGATATTCACTGACTA-1" "CGATTGAGTGTAATAC-1" "CGCATATAGTAAGTGG-1"
# [148] "CGCCACACAGCAACAG-1" "CGCTATGAGAGGAGTC-1" "CGCTCCATCGCATTAA-1"
# [151] "CGGACCTAGGGACCTC-1" "CGGCCATAGATGGACA-1" "CGGCTCACAGGCCATT-1"
# [154] "CGGGCTTAGTCTATGA-1" "CGGTGAACATAAGCAA-1" "CGTAACTAGGCCTTAG-1"
# [157] "CGTACGGGTGATGGCT-1" "CGTTAGTAGTATTGGC-1" "CGTTATTTCACAGGAA-1"
# [160] "CGTTATTTCGATATTG-1" "CGTTATTTCGTTTCGC-1" "CGTTTCTCATTAAGCT-1"
# [163] "CTAATAGTCATTACTC-1" "CTACTAAAGGACCAGG-1" "CTAGCTGAGTGCACGC-1"
# [166] "CTAGCTGAGTTAGAGG-1" "CTAGTCGAGCTCAATA-1" "CTATGATCATTAAGCT-1"
# [169] "CTATGATCATTGCGTA-1" "CTCAATAAGTCACCAG-1" "CTCAGGATCTGGCAAT-1"
# [172] "CTCATCATCGCTAAGT-1" "CTCATCATCGTGCTAG-1" "CTCATTAGTAACGGGA-1"
# [175] "CTCCTCACAGGGAGCT-1" "CTCTCACAGTAGCGGG-1" "CTCTTGATCTGTAATG-1"
# [178] "CTGAATATCTCACTAT-1" "CTGCAATAGGAGGACT-1" "CTGCTACTCGGTTTCC-1"
# [181] "CTGCTCCCAATTAGCT-1" "CTGGTTACAATATAGG-1" "CTGTTTAGTATTGGTG-1"
# [184] "CTTAACAAGCTAAAGG-1" "CTTACCGGTACCCACC-1" "CTTATTGGTTTACTTG-1"
# [187] "CTTCACTCAAAGCGGC-1" "CTTCGCGTCATGCTTT-1" "CTTGCATGTTTAGCGA-1"
# [190] "CTTGCATGTTTGAGCA-1" "CTTTAGGCACTTCATC-1" "CTTTCTTGTTTGGCGG-1"
# [193] "CTTTGAGCATGGTTAT-1" "CTTTGGGAGCGCATTG-1" "CTTTGGTGTCACCTAT-1"
# [196] "GAAACCCGTATTGTCC-1" "GAACTTATCTACCTAT-1" "GAAGTCAAGCTCCTTA-1"
# [199] "GACACCGGTTAACAGT-1" "GACCTCAAGTAACGAG-1" "GACTTACAGCGAGTAA-1"
# [202] "GAGCGAAGTGTTTCAC-1" "GAGCGGTCATGAGCAG-1" "GAGGCCTTCACACAGT-1"
# [205] "GAGGGAGCACGCAACT-1" "GAGTAACCAAGTTATC-1" "GAGTATCTCTCGCCCA-1"
# [208] "GAGTTTGGTTACGCGG-1" "GATAACGAGTAGAGGC-1" "GATCGATTCTTTAAGG-1"
# [211] "GATCGCTCAGTCTATG-1" "GATGGACAGCCGCTAA-1" "GATTCCTGTGAAGCCT-1"
# [214] "GATTGCGTCCAATTAG-1" "GATTGCGTCTTTGACT-1" "GATTGGTTCGGCTAGC-1"
# [217] "GATTGTTCAATGCGCT-1" "GCAATCTAGTAACGAG-1" "GCACCTAAGCTAATTG-1"
# [220] "GCATTAGGTTATCCTA-1" "GCCAATTAGTCACTAA-1" "GCCACTAAGTAAGTCC-1"
# [223] "GCCAGGTTCTAACCTT-1" "GCCATGATCCCTCTAA-1" "GCCCGTTGTTAACACG-1"
# [226] "GCCTCGACATTGCGAC-1" "GCCTGCTGTGGTGAGA-1" "GCGCAATGTCGCAAAC-1"
# [229] "GCGGATACAATCCTGA-1" "GCGGGTTTCCGTCCAT-1" "GCGTGCTAGGTCTTGG-1"
# [232] "GCGTGCTAGTCATGCG-1" "GCTAACCCAAGATTCT-1" "GCTAAGTTCTGGCATG-1"
# [235] "GCTAATATCGGCTAGC-1" "GCTATAGGTAACGTGC-1" "GCTCACAAGTTAGCTA-1"
# [238] "GCTGACATCAGAAACG-1" "GCTGAGGAGGCGCACT-1" "GCTGCAATCGCCTGTT-1"
# [241] "GCTGGATGTCTTACTA-1" "GCTGGTTCATTGCGAC-1" "GCTGTAAGTACCTTAC-1"
# [244] "GCTGTAAGTACGTTTC-1" "GCTGTAAGTGCTGGTG-1" "GCTTTACGTCCTAACT-1"
# [247] "GCTTTACGTGTTTGCT-1" "GCTTTATTCGTGCTAG-1" "GGAACCTGTTAGCGTA-1"
# [250] "GGACATAAGTATGTGC-1" "GGACATAAGTTATGTG-1" "GGACTAAAGAATCGCT-1"
# [253] "GGAGCATAGCATGTTA-1" "GGATAACCATAATGTC-1" "GGATTATGTATGGTGC-1"
# [256] "GGCATGGAGTAGCCAT-1" "GGCCAACTCCTTGAGG-1" "GGCGCTAGTGTCCAAA-1"
# [259] "GGCGGTTTCCCTCGCA-1" "GGCTATGTCATTACTC-1" "GGCTGAGAGTCATCCC-1"
# [262] "GGCTGGTTCCTAGTTT-1" "GGCTGGTTCGCAGGCT-1" "GGGTTACGTGATCAGC-1"
# [265] "GGGTTTGTCTTGAGGT-1" "GGTCAATTCTAGCGAT-1" "GGTCATTAGCATCCAG-1"
# [268] "GGTCATTAGCTTTGTT-1" "GGTGAGGTCTTTGACT-1" "GGTTACTAGCACCACA-1"
# [271] "GGTTCCCGTGGTTATG-1" "GGTTCCCGTTTGTCTA-1" "GTAAGCGCATCCTGAA-1"
# [274] "GTAAGCTTCGGTTACG-1" "GTAAGCTTCTAAGGAG-1" "GTACCTTGTCGTTATC-1"
# [277] "GTACTAATCCGCAAGC-1" "GTAGCGCTCTAAGTGC-1" "GTATCGCCACTTACAG-1"
# [280] "GTATGTTCATAATTGC-1" "GTATTCAAGTACTGGT-1" "GTCATCACAATATACC-1"
# [283] "GTCATGAGTAGTTAAC-1" "GTCCTCCCAAACTCAT-1" "GTCGAGGAGCACTAAC-1"
# [286] "GTCTATCGTTCCGGGA-1" "GTCTTGCTCACGCATG-1" "GTGAATCTCCCTGTTA-1"
# [289] "GTGATCAGTTGGCCGA-1" "GTGCTCCGTTCATCTA-1" "GTGTGTTAGCTGCACA-1"
# [292] "GTGTTACAGTGAAGTG-1" "GTTAACCAGGTCTTGG-1" "GTTAACGGTTCATTTG-1"
# [295] "GTTAAGCTCAGGGCCT-1" "GTTACAGGTGTTCCCA-1" "GTTCATTTCACTTTAC-1"
# [298] "GTTCATTTCTTGAGCG-1" "GTTCCCAGTACGGGTT-1" "GTTCCTTCATTAGGTT-1"
# [301] "GTTCTCATCCCTCAGT-1" "GTTGCTGAGCTATATG-1" "GTTGGAGCAGGACCTT-1"
# [304] "GTTTAACCAAGTTATC-1" "GTTTCTAGTTACATCC-1" "TAAACAGCACAGGAAT-1"
# [307] "TAATGCATCTTAGGGT-1" "TAATGGACAAGCTTAT-1" "TACATCAAGTTAGTTG-1"
# [310] "TACGTTAAGCTAATCA-1" "TACTAAGTCCTAGTAA-1" "TACTGGCCATTTGCTC-1"
# [313] "TAGCTAATCAGCAAGA-1" "TAGCTAGGTCTATCGT-1" "TAGGTGCGTGCTGTAA-1"
# [316] "TAGGTTATCGCACACA-1" "TAGTGAGAGGAACGGT-1" "TATCACGCAAGCTACC-1"
# [319] "TATCACGCATTGGGAG-1" "TATCGCGAGTCGCTAG-1" "TATGAAGCACGAATCC-1"
# [322] "TATGGTCAGGCCGGAA-1" "TATTCGTTCTAAGGTC-1" "TATTTGGAGTATCGCG-1"
# [325] "TATTTGGAGTTAGTTG-1" "TCAAACCAGTACCGCA-1" "TCAACAATCAGGCCTA-1"
# [328] "TCAAGACTCGTCCTTA-1" "TCAAGTATCCGCATGA-1" "TCACCGGCATCCGTAA-1"
# [331] "TCAGGTCCACGTAAGG-1" "TCAGGTTAGGATTGCT-1" "TCAGTAGGTAAGCACC-1"
# [334] "TCAGTAGGTGCACGCA-1" "TCATTACTCTGGTCCT-1" "TCCAGGATCATTTGTC-1"
# [337] "TCCATATTCTAGCGTG-1" "TCCATGCTCCATCAGG-1" "TCCGCCATCAAGACTC-1"
# [340] "TCGACAAGTTCCTGAT-1" "TCGCATTGTTAATGAC-1" "TCGCGCACACCTAAGC-1"
# [343] "TCGTTACGTACGTTTC-1" "TCGTTAGCAAAGGCCA-1" "TCGTTATTCCAATAGC-1"
# [346] "TCGTTTCCATAAACCT-1" "TCTAAGGGTGCTGGTG-1" "TCTAGCCTCAATTGGC-1"
# [349] "TCTTGTCCAGCCGCTA-1" "TGACTCCTCTTGGACG-1" "TGACTTAAGTGCTGTG-1"
# [352] "TGAGAACCACCGGCTA-1" "TGAGCCGGTATTGTCC-1" "TGAGCCGGTGCTTTAC-1"
# [355] "TGAGGAGGTCAATACG-1" "TGAGGTGCAAACCTAT-1" "TGATCAGGTTAGCCAA-1"
# [358] "TGATTGCAGAGGATAT-1" "TGCAATATCCTCAGTC-1" "TGCAATATCGGCTAGC-1"
# [361] "TGCACACCATGTTTGG-1" "TGCATGAGTCATAAGT-1" "TGCATTAAGCAAGATG-1"
# [364] "TGCGGTTCACGTGCTG-1" "TGCTGGATCGTAATCA-1" "TGCTTCCAGCACTAGT-1"
# [367] "TGCTTCCAGGTTACGT-1" "TGCTTGCTCTTTGTAC-1" "TGGATTCAGCATTTCT-1"
# [370] "TGGATTGGTTTGTCTA-1" "TGGCCATCAACTGGCT-1" "TGGCCATCATTAAGCT-1"
# [373] "TGGCGGTTCAATGTGC-1" "TGGTAAACAACTCGCG-1" "TGTCATAAGTTTGTCT-1"
# [376] "TGTGGCTCACATAACT-1" "TGTTGGCCAGCAAATA-1" "TGTTGGCCATGGTTAT-1"
# [379] "TGTTGTAAGGAGTAAT-1" "TTAACCAAGGGACTAA-1" "TTAACTGAGTTGGATC-1"
# [382] "TTAAGCCAGAGGAGTC-1" "TTAAGCCAGCAAGACA-1" "TTAAGGACAGGTTAAA-1"
# [385] "TTAGAAGCACAGGATG-1" "TTAGCTGCAGGAACAT-1" "TTAGGCTAGCAAGACA-1"
# [388] "TTATCCGTCCTTTACG-1" "TTATCCTAGGTGCTGC-1" "TTCACTGTCATGCCTC-1"
# [391] "TTCAGGTAGAGGCTAA-1" "TTCAGTTTCGAGGAGT-1" "TTCATCCCAGCATGTC-1"
# [394] "TTCATCCCATAGCGAG-1" "TTCGCAACACCGGCTA-1" "TTCGTGCTCTTAAGTG-1"
# [397] "TTGACGTAGTTTAACG-1" "TTGAGGCGTAAGCACC-1" "TTGTAAGTCCACCTTA-1"
# [400] "TTGTAAGTCCTGAATA-1" "TTGTCCCAGGAGGTTA-1" "TTGTGTGCAGTATGTT-1"
# [403] "TTGTTCCCAGCAAATA-1" "TTGTTGTTCGCTCCAT-1" "TTTAGCAAGGTCCGTA-1"
# [406] "TTTCCGGGTTGTGACA-1" "TTTGGTAAGCTATTGA-1" "TTTGTCTAGTTTGTCT-1"
# [409] "TTTGTGAAGGACAACA-1"

# %% [markdown]
# ## Peaks for 3 cell types of interest
# Loaded from previous MACS peak calling on all cell-types

# %%
# Create a granges object from bed file
file = file.path(sprintf("../macs_peaks_merged/%s_peaks.narrowPeak", cell.type))
df <- read.table(file, header = FALSE)

colnames(df) <- c("chr", "start", "end", "name", "score", 
                  "strand", "fold_change", "neg_log10pvalue_summit",
                  "neg_log10qvalue_summit", "relative_summit_position")

gr <- makeGRangesFromDataFrame(df, keep.extra.columns = TRUE)
gr <- keepStandardChromosomes(gr , pruning.mode = "coarse")
gr <- subsetByOverlaps(x = gr, ranges = blacklist_hg38_unified, invert = TRUE)
gr
# Out:
# GRanges object with 65569 ranges and 6 metadata columns:
#           seqnames            ranges strand |             name     score
#              <Rle>         <IRanges>  <Rle> |      <character> <integer>
#       [1]     chr1        9931-10455      * |    delta_peak_27       209
#       [2]     chr1     180720-181617      * |    delta_peak_28       302
#       [3]     chr1     190715-191881      * |    delta_peak_29       431
#       [4]     chr1     267846-268100      * |    delta_peak_30       164
#       [5]     chr1     586054-586265      * |    delta_peak_31        92
#       ...      ...               ...    ... .              ...       ...
#   [65565]     chrY 19076872-19077293      * | delta_peak_65685        42
#   [65566]     chrY 19566884-19567905      * | delta_peak_65686       166
#   [65567]     chrY 19744397-19744833      * | delta_peak_65687        56
#   [65568]     chrY 20575474-20576123      * | delta_peak_65688       169
#   [65569]     chrY 26670911-26671157      * | delta_peak_65689        74
#           fold_change neg_log10pvalue_summit neg_log10qvalue_summit
#             <numeric>              <numeric>              <numeric>
#       [1]    10.18990                24.0002               20.91130
#       [2]    12.18750                33.8860               30.29760
#       [3]    14.60670                47.7685               43.11580
#       [4]     8.78435                19.3048               16.43410
#       [5]     6.32473                11.7718                9.26784
#       ...         ...                    ...                    ...
#   [65565]     4.22078                6.49378                4.29911
#   [65566]     8.60927               19.51010               16.62990
#   [65567]     4.91924                7.95844                5.66779
#   [65568]     8.49057               19.81030               16.91640
#   [65569]     5.62199                9.81315                7.41464
#           relative_summit_position
#                          <integer>
#       [1]                      174
#       [2]                      718
#       [3]                      739
#       [4]                      165
#       [5]                       50
#       ...                      ...
#   [65565]                      356
#   [65566]                      280
#   [65567]                       82
#   [65568]                      193
#   [65569]                      149
#   -------
#   seqinfo: 24 sequences from an unspecified genome; no seqlengths

# %% [markdown]
# # Find counts in peaks and create ChromatinAssay object

# %%
cells <- subset(x = adata, idents = cell.type)

# %%
# First create a fragments object
fragments <- CreateFragmentObject(
    path = file.path(sprintf("../%s", sample), "atac_fragments.tsv.gz"),
    cells = ids,
    validate.fragments = TRUE)
# Out:
# Computing hash

# %%
# For parallelization of FeatureMatrix command
suppressMessages(library(future))
plan("multicore", workers = 16)  # Change based on availability, same for below

# %%
# Get the counts in fragments and store as a sparse matrix
counts <- FeatureMatrix(
    fragments = fragments,
    features = gr,
    cells = ids,
    process_n = 10000000
)
# Out:
# Extracting reads overlapping genomic regions

# %%
# create a new assay using the MACS2 peak set and add it to the Seurat object
cells[["peaks"]] <- CreateChromatinAssay(
    counts = counts,
    fragments = fragments,
    annotation = annotations,
    ranges = gr,
    genome = "hg38"
)

# %%
cells
# Out:
# An object of class Seurat
# 89819 features across 409 samples within 2 assays
# Active assay: peaks (65569 features, 0 variable features)
#  1 other assay present: SCT
#  1 dimensional reduction calculated: pca

# %% [markdown]
# # Link peaks to genes for this cell-type

# %%
# Alpha cells
DefaultAssay(cells) <- "peaks"
cells <- RegionStats(cells, genome = BSgenome.Hsapiens.UCSC.hg38)

# %%
# link peaks to genes. Adjust cut-offs so that all gene peak links are kept and non are discarded
cells <- LinkPeaks(
    object = cells,
    peak.assay = "peaks",
    expression.assay = "SCT",
    genes.use = c("SST"),
    method="pearson",
    pvalue_cutoff = 2,
    score_cutoff = 0
)
# Out:
# Testing 1 genes and 50483 peaks

# %%
# Save links to file
gr.links <- Links(cells)
linked.peaks <- gr.links$peak
chr.start.end <- unlist(strsplit(linked.peaks, "-"))
chr.start.end <- matrix(chr.start.end, length(chr.start.end)/3, 3, byrow = T)
seqs <- chr.start.end[, 1]
starts <- chr.start.end[, 2]
ends <- chr.start.end[, 3]
links.df <- data.frame(
    peak=gr.links$peak,
    gene=gr.links$gene,
    score=score(gr.links),
    zscore=gr.links$zscore,
    pvalue=gr.links$pvalue)
gr.peaks <- granges(cells)
gr.peaks$peak <- paste0(seqnames(gr.peaks), "-", start(gr.peaks), "-", end(gr.peaks))
annnotated.links <- merge(gr.peaks, links.df, by="peak", suffixes=c("_peaks", "_links"))
write.table(annnotated.links, 
            file=file.path("../indv_sample_networks", "correlation_links_shared-peaks", sprintf("%s.%s.links.tsv", sample, cell.type)),
            quote=F, sep="\t", row.names=F, col.names=T)

# %%
# Save object to file
saveRDS(cells, file = file.path("../indv_sample_networks", "correlation_links_shared-peaks", 
                                      sprintf("%s.%s.linked.rds", sample, cell.type)))

# %% [markdown]
# # Scratch
# Place for old or testing code

# %% [markdown]
# # References
