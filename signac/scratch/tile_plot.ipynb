# %%
suppressMessages(library(Seurat))
suppressMessages(library(Signac))

# %%
fpath <- "/cellar/users/aklie/data/datasets/igvf_sc-islet_10X-Multiome/processed/21Jul23/cellranger/igvf_dm32a_deep/outs/atac_fragments.tsv.gz"

# %%
adata <- readRDS("/cellar/users/aklie/data/datasets/igvf_sc-islet_10X-Multiome/annotation/previous/17Aug23/seurat/17aug23_year1_year2_all.rds")

# %%
fragments <- CreateFragmentObject(
  path = fpath,
  cells = colnames(adata),
  validate.fragments = FALSE
)
# Out:
# Computing hash

# %%
adata
# Out:
# An object of class Seurat
# 330784 features across 83289 samples within 3 assays
# Active assay: mpeak (262611 features, 0 variable features)
#  2 other assays present: RNA, SCT
#  6 dimensional reductions calculated: pca, harmony, lsi, atac.harmony, umap.wnn, sct.harmony

# %%
DefaultAssay(adata) <- "mpeak"

# %%
Fragments(adata) <- NULL

# %%
Fragments(adata) <- fragments

# %%
adata@meta.data
# Out:
#                         orig.ident    nCount_RNA nFeature_RNA percent.mt
# MO1_AAACAGCCAGCAATAA-1  SeuratProject  7140.390  2937         0.000000000
# MO1_AAACCAACAACCGCCA-1  SeuratProject  5083.687  2651         0.000000000
# MO1_AAACCGCGTATTGTGG-1  SeuratProject  8302.654  3797         0.000000000
# MO1_AAACGCGCAAGCCACT-1  SeuratProject  5772.429  3107         0.005387824
# MO1_AAACGCGCAGTTATCG-1  SeuratProject  2732.243  1822         0.140443460
# MO1_AAACGTACACCAGCAT-1  SeuratProject  2919.482  1834         0.116800003
# MO1_AAAGCACCAAGCTTTG-1  SeuratProject  2645.573  1714         0.063044568
# MO1_AAAGCACCACCGGTAT-1  SeuratProject  3678.389  2312         0.047543412
# MO1_AAAGCCGCATTGTGAT-1  SeuratProject  8040.695  3160         0.000000000
# MO1_AAAGCGGGTTTACTTG-1  SeuratProject  5849.512  2793         0.000000000
# MO1_AAAGCTTGTACCTTAC-1  SeuratProject  8745.176  3611         0.000000000
# MO1_AAAGCTTGTGATGATT-1  SeuratProject  2582.404  1856         0.265589419
# ...

# %%
# Computing hash
TilePlot(object = adata, region = c("chr2-87011729-87050000"), assay = "mpeak", group.by="predicted.cell.type", tile.size=100, tile.cells=50)
# Out:
# plot without title

# %% [markdown]
# # DONE!

# %% [markdown]
# ---
